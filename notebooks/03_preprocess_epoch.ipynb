# %% [markdown]
# # 03. YOTO preprocessing and tone epoching

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd() if (Path.cwd() / "configs").exists() else Path.cwd().parent
os.chdir(ROOT)
sys.path.insert(0, str(ROOT))

DATA_ROOT = ROOT / "data"
MANIFESTS = DATA_ROOT / "manifests"

DATASET_CONFIGS = [
    {
        "dataset_id": "ds005815",
        "task_contains": "task-task",
        "out_dir": DATA_ROOT / "processed/epochs_yoto_tones",
        "out_index": MANIFESTS / "epoch_index_yoto_tones.csv",
    }
]

SKIP_ASR = True
SKIP_ICA = True

# %%
from scripts.preprocess_yoto import run_preprocess_yoto

summaries = []
for cfg in DATASET_CONFIGS:
    summaries.append(
        run_preprocess_yoto(
            dataset_id=cfg["dataset_id"],
            task_contains=cfg["task_contains"],
            out_dir=cfg["out_dir"],
            out_index=cfg["out_index"],
            skip_asr=SKIP_ASR,
            skip_ica=SKIP_ICA,
        )
    )

summaries
# Out:
# using event value to stimulus mapping
# using event value to stimulus mapping
# using event value to stimulus mapping
# event_mapping: {27: 'tone_C', 28: 'tone_D', 29: 'tone_E'}
# cfg_events: {'dataset_id': 'ds005815', 'event_value_to_stimulus': {27: 'tone_C', 28: 'tone_D', 29: 'tone_E'}, 'trial_type_to_stimulus': {}, 'stimuli': {'tone_C': {'frequency_hz': 261.63}, 'tone_D': {'frequency_hz': 293.66}, 'tone_E': {'frequency_hz': 329.63}}}
# valid stimulus tone_E starts at 30531 samples and ends at 30781 samples in data.shape: (30, 536870)
# onset at 122.325
# valid stimulus tone_C starts at 45378 samples and ends at 45628 samples in data.shape: (30, 536870)
# onset at 181.71
# valid stimulus tone_E starts at 47819 samples and ends at 48069 samples in data.shape: (30, 536870)
# onset at 191.476
# valid stimulus tone_C starts at 75599 samples and ends at 75849 samples in data.shape: (30, 536870)
# onset at 302.595
# valid stimulus tone_D starts at 92970 samples and ends at 93220 samples in data.shape: (30, 536870)
# onset at 372.079
# valid stimulus tone_D starts at 115408 samples and ends at 115658 samples in data.shape: (30, 536870)
# onset at 461.83
# valid stimulus tone_D starts at 144720 samples and ends at 144970 samples in data.shape: (30, 536870)
# onset at 579.082
# valid stimulus tone_C starts at 164616 samples and ends at 164866 samples in data.shape: (30, 536870)
# onset at 658.666
# valid stimulus tone_E starts at 184658 samples and ends at 184908 samples in data.shape: (30, 536870)
# onset at 738.834
# valid stimulus tone_E starts at 197396 samples and ends at 197646 samples in data.shape: (30, 536870)
# onset at 789.785
# valid stimulus tone_D starts at 202413 samples and ends at 202663 samples in data.shape: (30, 536870)
# onset at 809.852
# valid stimulus tone_C starts at 224938 samples and ends at 225188 samples in data.shape: (30, 536870)
# onset at 899.953
# valid stimulus tone_C starts at 291022 samples and ends at 291272 samples in data.shape: (30, 536870)
# onset at 1164.29
# valid stimulus tone_D starts at 305414 samples and ends at 305664 samples in data.shape: (30, 536870)
# onset at 1221.858
# valid stimulus tone_C starts at 317640 samples and ends at 317890 samples in data.shape: (30, 536870)
# onset at 1270.759
# valid stimulus tone_E starts at 342369 samples and ends at 342619 samples in data.shape: (30, 536870)
# onset at 1369.677
# valid stimulus tone_E starts at 347390 samples and ends at 347640 samples in data.shape: (30, 536870)
# onset at 1389.761
# valid stimulus tone_D starts at 357157 samples and ends at 357407 samples in data.shape: (30, 536870)
# onset at 1428.828
# valid stimulus tone_E starts at 483509 samples and ends at 483759 samples in data.shape: (30, 536870)
# onset at 1934.235
# valid stimulus tone_D starts at 488267 samples and ends at 488517 samples in data.shape: (30, 536870)
# onset at 1953.269
# valid stimulus tone_D starts at 493122 samples and ends at 493372 samples in data.shape: (30, 536870)
# onset at 1972.686
# valid stimulus tone_C starts at 502822 samples and ends at 503072 samples in data.shape: (30, 536870)
# onset at 2011.486
# valid stimulus tone_E starts at 513022 samples and ends at 513272 samples in data.shape: (30, 536870)
# onset at 2052.287
# valid stimulus tone_C starts at 522576 samples and ends at 522826 samples in data.shape: (30, 536870)
# onset at 2090.504
# epochs: (24, 30, 250), valid_starts: [30531, 45378, 47819, 75599, 92970, 115408, 144720, 164616, 184658, 197396, 202413, 224938, 291022, 305414, 317640, 342369, 347390, 357157, 483509, 488267, 493122, 502822, 513022, 522576], stimulus_ids: ['tone_E', 'tone_C', 'tone_E', 'tone_C', 'tone_D', 'tone_D', 'tone_D', 'tone_C', 'tone_E', 'tone_E', 'tone_D', 'tone_C', 'tone_C', 'tone_D', 'tone_C', 'tone_E', 'tone_E', 'tone_D', 'tone_E', 'tone_D', 'tone_D', 'tone_C', 'tone_E', 'tone_C']
# the subject had a total of 24 valid stimuli + 173 invalid stimuli
# subject_id: sub-08
# index_rows: [{'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 0, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 1, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 2, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 3, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 4, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 5, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 6, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 7, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 8, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 9, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 10, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': ...
# valid stimulus tone_C starts at 9574 samples and ends at 9824 samples in data.shape: (30, 302012)
# onset at 38.495
# valid stimulus tone_D starts at 46308 samples and ends at 46558 samples in data.shape: (30, 302012)
# onset at 185.431
# valid stimulus tone_D starts at 54491 samples and ends at 54741 samples in data.shape: (30, 302012)
# onset at 218.165
# valid stimulus tone_E starts at 57612 samples and ends at 57862 samples in data.shape: (30, 302012)
# onset at 230.648
# valid stimulus tone_C starts at 60079 samples and ends at 60329 samples in data.shape: (30, 302012)
# onset at 240.515
# valid stimulus tone_E starts at 90550 samples and ends at 90800 samples in data.shape: (30, 302012)
# onset at 362.4
# valid stimulus tone_E starts at 160447 samples and ends at 160697 samples in data.shape: (30, 302012)
# onset at 641.988
# valid stimulus tone_E starts at 189589 samples and ends at 189839 samples in data.shape: (30, 302012)
# onset at 758.556
# valid stimulus tone_D starts at 197506 samples and ends at 197756 samples in data.shape: (30, 302012)
# onset at 790.224
# valid stimulus tone_D starts at 207652 samples and ends at 207902 samples in data.shape: (30, 302012)
# onset at 830.807
# valid stimulus tone_C starts at 233648 samples and ends at 233898 samples in data.shape: (30, 302012)
# onset at 934.792
# valid stimulus tone_C starts at 248952 samples and ends at 249202 samples in data.shape: (30, 302012)
# onset at 996.01
# valid stimulus tone_E starts at 329391 samples and ends at 329641 samples in data.shape: (30, 302012)
# onset at 1317.765
# valid stimulus tone_D starts at 331870 samples and ends at 332120 samples in data.shape: (30, 302012)
# onset at 1327.682
# valid stimulus tone_E starts at 337141 samples and ends at 337391 samples in data.shape: (30, 302012)
# onset at 1348.765
# valid stimulus tone_C starts at 345596 samples and ends at 345846 samples in data.shape: (30, 302012)
# onset at 1382.582
# valid stimulus tone_C starts at 351046 samples and ends at 351296 samples in data.shape: (30, 302012)
# onset at 1404.383
# valid stimulus tone_D starts at 361854 samples and ends at 362104 samples in data.shape: (30, 302012)
# onset at 1447.617
# valid stimulus tone_D starts at 387750 samples and ends at 388000 samples in data.shape: (30, 302012)
# onset at 1551.202
# valid stimulus tone_E starts at 395272 samples and ends at 395522 samples in data.shape: (30, 302012)
# onset at 1581.286
# valid stimulus tone_E starts at 400255 samples and ends at 400505 samples in data.shape: (30, 302012)
# onset at 1601.219
# valid stimulus tone_D starts at 425984 samples and ends at 426234 samples in data.shape: (30, 302012)
# onset at 1704.137
# valid stimulus tone_C starts at 442147 samples and ends at 442397 samples in data.shape: (30, 302012)
# onset at 1768.788
# valid stimulus tone_C starts at 491231 samples and ends at 491481 samples in data.shape: (30, 302012)
# onset at 1965.125
# epochs: (12, 30, 250), valid_starts: [9574, 46308, 54491, 57612, 60079, 90550, 160447, 189589, 197506, 207652, 233648, 248952], stimulus_ids: ['tone_C', 'tone_D', 'tone_D', 'tone_E', 'tone_C', 'tone_E', 'tone_E', 'tone_E', 'tone_D', 'tone_D', 'tone_C', 'tone_C']
# the subject had a total of 12 valid stimuli + 185 invalid stimuli
# subject_id: sub-01
# index_rows: [{'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 0, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 1, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 2, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 3, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 4, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 5, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 6, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 7, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 8, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 9, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 10, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': ...
# valid stimulus tone_C starts at 38718 samples and ends at 38968 samples in data.shape: (30, 506970)
# onset at 155.074
# valid stimulus tone_C starts at 72911 samples and ends at 73161 samples in data.shape: (30, 506970)
# onset at 291.843
# valid stimulus tone_C starts at 167192 samples and ends at 167442 samples in data.shape: (30, 506970)
# onset at 668.966
# valid stimulus tone_C starts at 169912 samples and ends at 170162 samples in data.shape: (30, 506970)
# onset at 679.849
# valid stimulus tone_C starts at 259185 samples and ends at 259435 samples in data.shape: (30, 506970)
# onset at 1036.938
# valid stimulus tone_C starts at 335019 samples and ends at 335269 samples in data.shape: (30, 506970)
# onset at 1340.276
# valid stimulus tone_C starts at 428724 samples and ends at 428974 samples in data.shape: (30, 506970)
# onset at 1715.098
# valid stimulus tone_C starts at 470121 samples and ends at 470371 samples in data.shape: (30, 506970)
# onset at 1880.684
# valid stimulus tone_D starts at 44185 samples and ends at 44435 samples in data.shape: (30, 506970)
# onset at 176.941
# valid stimulus tone_D starts at 100561 samples and ends at 100811 samples in data.shape: (30, 506970)
# onset at 402.445
# valid stimulus tone_D starts at 177354 samples and ends at 177604 samples in data.shape: (30, 506970)
# onset at 709.616
# valid stimulus tone_D starts at 187612 samples and ends at 187862 samples in data.shape: (30, 506970)
# onset at 750.65
# valid stimulus tone_D starts at 352698 samples and ends at 352948 samples in data.shape: (30, 506970)
# onset at 1410.994
# valid stimulus tone_D starts at 355265 samples and ends at 355515 samples in data.shape: (30, 506970)
# onset at 1421.26
# valid stimulus tone_D starts at 464542 samples and ends at 464792 samples in data.shape: (30, 506970)
# onset at 1858.367
# valid stimulus tone_D starts at 485959 samples and ends at 486209 samples in data.shape: (30, 506970)
# onset at 1944.035
# valid stimulus tone_E starts at 68082 samples and ends at 68332 samples in data.shape: (30, 506970)
# onset at 272.526
# valid stimulus tone_E starts at 95394 samples and ends at 95644 samples in data.shape: (30, 506970)
# onset at 381.778
# valid stimulus tone_E starts at 153941 samples and ends at 154191 samples in data.shape: (30, 506970)
# onset at 615.965
# valid stimulus tone_E starts at 156416 samples and ends at 156666 samples in data.shape: (30, 506970)
# onset at 625.865
# valid stimulus tone_E starts at 266647 samples and ends at 266897 samples in data.shape: (30, 506970)
# onset at 1066.788
# valid stimulus tone_E starts at 329406 samples and ends at 329656 samples in data.shape: (30, 506970)
# onset at 1317.825
# valid stimulus tone_E starts at 399262 samples and ends at 399512 samples in data.shape: (30, 506970)
# onset at 1597.246
# valid stimulus tone_E starts at 444183 samples and ends at 444433 samples in data.shape: (30, 506970)
# onset at 1776.932
# epochs: (24, 30, 250), valid_starts: [38718, 72911, 167192, 169912, 259185, 335019, 428724, 470121, 44185, 100561, 177354, 187612, 352698, 355265, 464542, 485959, 68082, 95394, 153941, 156416, 266647, 329406, 399262, 444183], stimulus_ids: ['tone_C', 'tone_C', 'tone_C', 'tone_C', 'tone_C', 'tone_C', 'tone_C', 'tone_C', 'tone_D', 'tone_D', 'tone_D', 'tone_D', 'tone_D', 'tone_D', 'tone_D', 'tone_D', 'tone_E', 'tone_E', 'tone_E', 'tone_E', 'tone_E', 'tone_E', 'tone_E', 'tone_E']
# the subject had a total of 24 valid stimuli + 173 invalid stimuli
# subject_id: sub-01
# index_rows: [{'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 0, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 1, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 2, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 3, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 4, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 5, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 6, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 7, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 8, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 9, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 10, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': ...
# valid stimulus tone_C starts at 16672 samples and ends at 16922 samples in data.shape: (30, 301466)
# onset at 66.888
# valid stimulus tone_C starts at 23964 samples and ends at 24214 samples in data.shape: (30, 301466)
# onset at 96.055
# valid stimulus tone_E starts at 33572 samples and ends at 33822 samples in data.shape: (30, 301466)
# onset at 134.489
# valid stimulus tone_E starts at 81660 samples and ends at 81910 samples in data.shape: (30, 301466)
# onset at 326.842
# valid stimulus tone_D starts at 97452 samples and ends at 97702 samples in data.shape: (30, 301466)
# onset at 390.009
# valid stimulus tone_D starts at 114719 samples and ends at 114969 samples in data.shape: (30, 301466)
# onset at 459.077
# valid stimulus tone_C starts at 144216 samples and ends at 144466 samples in data.shape: (30, 301466)
# onset at 577.062
# valid stimulus tone_E starts at 158386 samples and ends at 158636 samples in data.shape: (30, 301466)
# onset at 633.746
# valid stimulus tone_D starts at 176249 samples and ends at 176499 samples in data.shape: (30, 301466)
# onset at 705.197
# valid stimulus tone_E starts at 181300 samples and ends at 181550 samples in data.shape: (30, 301466)
# onset at 725.398
# valid stimulus tone_C starts at 229763 samples and ends at 230013 samples in data.shape: (30, 301466)
# onset at 919.251
# valid stimulus tone_D starts at 238808 samples and ends at 239058 samples in data.shape: (30, 301466)
# onset at 955.434
# valid stimulus tone_D starts at 273459 samples and ends at 273709 samples in data.shape: (30, 301466)
# onset at 1094.037
# valid stimulus tone_E starts at 290876 samples and ends at 291126 samples in data.shape: (30, 301466)
# onset at 1163.704
# valid stimulus tone_C starts at 306489 samples and ends at 306739 samples in data.shape: (30, 301466)
# onset at 1226.155
# valid stimulus tone_D starts at 333331 samples and ends at 333581 samples in data.shape: (30, 301466)
# onset at 1333.523
# valid stimulus tone_C starts at 366406 samples and ends at 366656 samples in data.shape: (30, 301466)
# onset at 1465.825
# valid stimulus tone_E starts at 401936 samples and ends at 402186 samples in data.shape: (30, 301466)
# onset at 1607.944
# valid stimulus tone_E starts at 551388 samples and ends at 551638 samples in data.shape: (30, 301466)
# onset at 2205.753
# valid stimulus tone_D starts at 565505 samples and ends at 565755 samples in data.shape: (30, 301466)
# onset at 2262.22
# valid stimulus tone_E starts at 579893 samples and ends at 580143 samples in data.shape: (30, 301466)
# onset at 2319.771
# valid stimulus tone_C starts at 584593 samples and ends at 584843 samples in data.shape: (30, 301466)
# onset at 2338.571
# valid stimulus tone_C starts at 594235 samples and ends at 594485 samples in data.shape: (30, 301466)
# onset at 2377.139
# valid stimulus tone_D starts at 619977 samples and ends at 620227 samples in data.shape: (30, 301466)
# onset at 2480.107
# epochs: (14, 30, 250), valid_starts: [16672, 23964, 33572, 81660, 97452, 114719, 144216, 158386, 176249, 181300, 229763, 238808, 273459, 290876], stimulus_ids: ['tone_C', 'tone_C', 'tone_E', 'tone_E', 'tone_D', 'tone_D', 'tone_C', 'tone_E', 'tone_D', 'tone_E', 'tone_C', 'tone_D', 'tone_D', 'tone_E']
# the subject had a total of 14 valid stimuli + 183 invalid stimuli
# subject_id: sub-05
# index_rows: [{'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 0, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 1, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 2, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 3, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 4, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 5, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 6, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 7, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 8, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 9, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 10, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': ...
# valid stimulus tone_E starts at 42880 samples and ends at 43130 samples in data.shape: (30, 302012)
# onset at 171.72
# valid stimulus tone_E starts at 59159 samples and ends at 59409 samples in data.shape: (30, 302012)
# onset at 236.837
# valid stimulus tone_C starts at 84552 samples and ends at 84802 samples in data.shape: (30, 302012)
# onset at 338.406
# valid stimulus tone_C starts at 89639 samples and ends at 89889 samples in data.shape: (30, 302012)
# onset at 358.756
# valid stimulus tone_D starts at 100068 samples and ends at 100318 samples in data.shape: (30, 302012)
# onset at 400.473
# valid stimulus tone_D starts at 145432 samples and ends at 145682 samples in data.shape: (30, 302012)
# onset at 581.926
# valid stimulus tone_C starts at 161986 samples and ends at 162236 samples in data.shape: (30, 302012)
# onset at 648.144
# valid stimulus tone_E starts at 188616 samples and ends at 188866 samples in data.shape: (30, 302012)
# onset at 754.662
# valid stimulus tone_D starts at 199024 samples and ends at 199274 samples in data.shape: (30, 302012)
# onset at 796.296
# valid stimulus tone_C starts at 201886 samples and ends at 202136 samples in data.shape: (30, 302012)
# onset at 807.746
# valid stimulus tone_E starts at 276592 samples and ends at 276842 samples in data.shape: (30, 302012)
# onset at 1106.567
# valid stimulus tone_D starts at 284958 samples and ends at 285208 samples in data.shape: (30, 302012)
# onset at 1140.034
# valid stimulus tone_C starts at 310092 samples and ends at 310342 samples in data.shape: (30, 302012)
# onset at 1240.569
# valid stimulus tone_D starts at 312696 samples and ends at 312946 samples in data.shape: (30, 302012)
# onset at 1250.986
# valid stimulus tone_C starts at 336755 samples and ends at 337005 samples in data.shape: (30, 302012)
# onset at 1347.22
# valid stimulus tone_E starts at 344634 samples and ends at 344884 samples in data.shape: (30, 302012)
# onset at 1378.738
# valid stimulus tone_D starts at 381172 samples and ends at 381422 samples in data.shape: (30, 302012)
# onset at 1524.89
# valid stimulus tone_E starts at 399152 samples and ends at 399402 samples in data.shape: (30, 302012)
# onset at 1596.807
# valid stimulus tone_D starts at 501799 samples and ends at 502049 samples in data.shape: (30, 302012)
# onset at 2007.397
# valid stimulus tone_C starts at 504499 samples and ends at 504749 samples in data.shape: (30, 302012)
# onset at 2018.197
# valid stimulus tone_E starts at 526858 samples and ends at 527108 samples in data.shape: (30, 302012)
# onset at 2107.632
# valid stimulus tone_E starts at 534704 samples and ends at 534954 samples in data.shape: (30, 302012)
# onset at 2139.015
# valid stimulus tone_D starts at 544792 samples and ends at 545042 samples in data.shape: (30, 302012)
# onset at 2179.366
# valid stimulus tone_C starts at 569313 samples and ends at 569563 samples in data.shape: (30, 302012)
# onset at 2277.451
# epochs: (12, 30, 250), valid_starts: [42880, 59159, 84552, 89639, 100068, 145432, 161986, 188616, 199024, 201886, 276592, 284958], stimulus_ids: ['tone_E', 'tone_E', 'tone_C', 'tone_C', 'tone_D', 'tone_D', 'tone_C', 'tone_E', 'tone_D', 'tone_C', 'tone_E', 'tone_D']
# the subject had a total of 12 valid stimuli + 185 invalid stimuli
# subject_id: sub-02
# index_rows: [{'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 0, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 1, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 2, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 3, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 4, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 5, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 6, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 7, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 8, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 9, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 10, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': ...
# valid stimulus tone_C starts at 26505 samples and ends at 26755 samples in data.shape: (30, 302012)
# onset at 106.22
# valid stimulus tone_D starts at 42047 samples and ends at 42297 samples in data.shape: (30, 302012)
# onset at 168.388
# valid stimulus tone_E starts at 62785 samples and ends at 63035 samples in data.shape: (30, 302012)
# onset at 251.339
# valid stimulus tone_D starts at 73106 samples and ends at 73356 samples in data.shape: (30, 302012)
# onset at 292.623
# valid stimulus tone_C starts at 104314 samples and ends at 104564 samples in data.shape: (30, 302012)
# onset at 417.458
# valid stimulus tone_E starts at 136715 samples and ends at 136965 samples in data.shape: (30, 302012)
# onset at 547.06
# valid stimulus tone_D starts at 160690 samples and ends at 160940 samples in data.shape: (30, 302012)
# onset at 642.962
# valid stimulus tone_E starts at 165678 samples and ends at 165928 samples in data.shape: (30, 302012)
# onset at 662.912
# valid stimulus tone_C starts at 175562 samples and ends at 175812 samples in data.shape: (30, 302012)
# onset at 702.446
# valid stimulus tone_E starts at 183170 samples and ends at 183420 samples in data.shape: (30, 302012)
# onset at 732.88
# valid stimulus tone_D starts at 226133 samples and ends at 226383 samples in data.shape: (30, 302012)
# onset at 904.732
# valid stimulus tone_C starts at 260200 samples and ends at 260450 samples in data.shape: (30, 302012)
# onset at 1041.001
# valid stimulus tone_D starts at 338918 samples and ends at 339168 samples in data.shape: (30, 302012)
# onset at 1355.873
# valid stimulus tone_C starts at 341539 samples and ends at 341789 samples in data.shape: (30, 302012)
# onset at 1366.356
# valid stimulus tone_C starts at 352027 samples and ends at 352277 samples in data.shape: (30, 302012)
# onset at 1408.307
# valid stimulus tone_E starts at 364773 samples and ends at 365023 samples in data.shape: (30, 302012)
# onset at 1459.291
# valid stimulus tone_E starts at 384156 samples and ends at 384406 samples in data.shape: (30, 302012)
# onset at 1536.825
# valid stimulus tone_D starts at 391452 samples and ends at 391702 samples in data.shape: (30, 302012)
# onset at 1566.009
# valid stimulus tone_D starts at 451695 samples and ends at 451945 samples in data.shape: (30, 302012)
# onset at 1806.979
# valid stimulus tone_C starts at 457258 samples and ends at 457508 samples in data.shape: (30, 302012)
# onset at 1829.23
# valid stimulus tone_E starts at 489546 samples and ends at 489796 samples in data.shape: (30, 302012)
# onset at 1958.382
# valid stimulus tone_D starts at 500812 samples and ends at 501062 samples in data.shape: (30, 302012)
# onset at 2003.449
# valid stimulus tone_C starts at 534913 samples and ends at 535163 samples in data.shape: (30, 302012)
# onset at 2139.851
# valid stimulus tone_E starts at 550813 samples and ends at 551063 samples in data.shape: (30, 302012)
# onset at 2203.452
# epochs: (12, 30, 250), valid_starts: [26505, 42047, 62785, 73106, 104314, 136715, 160690, 165678, 175562, 183170, 226133, 260200], stimulus_ids: ['tone_C', 'tone_D', 'tone_E', 'tone_D', 'tone_C', 'tone_E', 'tone_D', 'tone_E', 'tone_C', 'tone_E', 'tone_D', 'tone_C']
# the subject had a total of 12 valid stimuli + 185 invalid stimuli
# subject_id: sub-02
# index_rows: [{'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 0, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 1, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 2, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 3, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 4, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 5, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 6, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 7, 'stimulus_id': 'tone_C', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 8, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 9, 'stimulus_id': 'tone_E', 'n_channels': 30, 'n_samples': 250}, {'dataset_id': 'ds005815', 'subject_id': 'sub-08', 'source_file': 'data/raw_samples/ds005815/sub-08/ses-1/eeg/sub-08_ses-1_task-task_eeg.vhdr', 'epochs_file': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones/ds005815__sub-08__sub-08_ses-1_task-task_eeg.npy', 'epoch_idx': 10, 'stimulus_id': 'tone_D', 'n_channels': 30, 'n_samples': ...
# Saved 98 epoch rows to /Users/alexandra.feldman/thesis/identify/data/manifests/epoch_index_yoto_tones.csv
# [{'dataset_id': 'ds005815',
#   'n_vhdr': 7,
#   'n_epochs': 98,
#   'out_index': '/Users/alexandra.feldman/thesis/identify/data/manifests/epoch_index_yoto_tones.csv',
#   'out_dir': '/Users/alexandra.feldman/thesis/identify/data/processed/epochs_yoto_tones'}]
